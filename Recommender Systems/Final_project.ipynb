# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from math import sqrt
# %matplotlib inline

# %%
df_big=pd.read_csv("/home/tiredninja/Ml  Course/Databases/reviews.csv")
df_big.head()
# Out:
#          asin           name  rating               date  verified  \
# 0  B0000SX2UC          Janet       3   October 11, 2005     False
# 1  B0000SX2UC     Luke Wyatt       1    January 7, 2004     False
# 2  B0000SX2UC         Brooke       5  December 30, 2003     False
# 3  B0000SX2UC  amy m. teague       3     March 18, 2004     False
# 4  B0000SX2UC  tristazbimmer       4    August 28, 2005     False
#
#                                           title  \
# 0                   Def not best, but not worst
# 1                   Text Messaging Doesn't Work
# 2                               Love This Phone
# 3                       Love the Phone, BUT...!
# 4  Great phone service and options, lousy case!
#
#                                                 body  helpfulVotes
# 0  I had the Samsung A600 for awhile which is abs...           1.0
# 1  Due to a software issue between Nokia and Spri...          17.0
# 2  This is a great, reliable phone. I also purcha...           5.0
# ...

# %%
df_big.shape
# Out:
# (67986, 8)

# %%
df_2=pd.read_csv("/home/tiredninja/Ml  Course/Databases/items.csv")
df_2.head()
# Out:
#          asin     brand                                              title  \
# 0  B0000SX2UC       NaN  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1  B0009N5L7K  Motorola                                Motorola I265 phone
# 2  B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3  B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# 4  B001DCJAJG  Motorola      Motorola V365 no contract cellular phone AT&T
#
#                                                  url  \
# 0  https://www.amazon.com/Dual-Band-Tri-Mode-Acti...
# 1  https://www.amazon.com/Motorola-i265-I265-phon...
# 2  https://www.amazon.com/MOTOROLA-C168i-CINGULAR...
# 3  https://www.amazon.com/Motorola-i335-Phone-Boo...
# 4  https://www.amazon.com/Motorola-V365-contract-...
#
#                                                image  rating  \
# 0  https://m.media-amazon.com/images/I/2143EBQ210...     3.0
# 1  https://m.media-amazon.com/images/I/419WBAVDAR...     3.0
# ...

# %%
# majbor be estefade az data aval darim chon age dotaro merge konim data az 60k  miad ro 800  va arzesh nadare

# %%
df_2.shape
# Out:
# (720, 10)

# %%
df_2=df_2.drop("url",axis=1)
df_2=df_2.drop("image",axis=1)
df_2=df_2.drop("reviewUrl",axis=1)
df_2=df_2.drop("originalPrice",axis=1)
df_2=df_2.drop("totalReviews",axis=1)
df_2=df_2.drop("brand",axis=1)
df_2=df_2.drop("title",axis=1)

# %%
df_big.head()
# Out:
#          asin           name  rating               date  verified  \
# 0  B0000SX2UC          Janet       3   October 11, 2005     False
# 1  B0000SX2UC     Luke Wyatt       1    January 7, 2004     False
# 2  B0000SX2UC         Brooke       5  December 30, 2003     False
# 3  B0000SX2UC  amy m. teague       3     March 18, 2004     False
# 4  B0000SX2UC  tristazbimmer       4    August 28, 2005     False
#
#                                           title  \
# 0                   Def not best, but not worst
# 1                   Text Messaging Doesn't Work
# 2                               Love This Phone
# 3                       Love the Phone, BUT...!
# 4  Great phone service and options, lousy case!
#
#                                                 body  helpfulVotes
# 0  I had the Samsung A600 for awhile which is abs...           1.0
# 1  Due to a software issue between Nokia and Spri...          17.0
# 2  This is a great, reliable phone. I also purcha...           5.0
# ...

# %%
df_big=df_big.drop("date",axis=1)
df_big=df_big.drop("body",axis=1)
df_big=df_big.drop("title",axis=1)
df_big=df_big.drop("helpfulVotes",axis=1)

# %%
df_big.head()
# Out:
#          asin           name  rating  verified
# 0  B0000SX2UC          Janet       3     False
# 1  B0000SX2UC     Luke Wyatt       1     False
# 2  B0000SX2UC         Brooke       5     False
# 3  B0000SX2UC  amy m. teague       3     False
# 4  B0000SX2UC  tristazbimmer       4     False

# %%
df_2.head()
# Out:
#          asin  rating   price
# 0  B0000SX2UC     3.0    0.00
# 1  B0009N5L7K     3.0   49.95
# 2  B000SKTZ0S     2.7   99.99
# 3  B001AO4OUC     3.3    0.00
# 4  B001DCJAJG     3.1  149.99

# %%
total_df = df_big.copy()
total_df
# Out:
#              asin               name  rating  verified
# 0      B0000SX2UC              Janet       3     False
# 1      B0000SX2UC         Luke Wyatt       1     False
# 2      B0000SX2UC             Brooke       5     False
# 3      B0000SX2UC      amy m. teague       3     False
# 4      B0000SX2UC      tristazbimmer       4     False
# ...           ...                ...     ...       ...
# 67981  B081H6STQQ              jande       5     False
# 67982  B081H6STQQ            2cool4u       5     False
# 67983  B081H6STQQ              simon       5     False
# 67984  B081TJFVCJ  Tobiasz Jedrysiak       5      True
# 67985  B0825BB7SG      Owen Gonzalez       5     False
#
# [67986 rows x 4 columns]

# %%
df_2["asin"].tolist()
# Out:
# ['B0000SX2UC',
#  'B0009N5L7K',
#  'B000SKTZ0S',
#  'B001AO4OUC',
#  'B001DCJAJG',
#  'B001GQ3DJM',
#  'B0029F2O3A',
#  'B002AS9WEA',
#  'B002UHS0UI',
#  'B002WTC1NG',
#  'B0033SFV5A',
#  'B003FCO9XE',
#  'B003P2VNAQ',
#  'B003W646YK',
#  'B003XREZ4O',
#  'B0046REOWS',
#  'B004C7NVD0',
#  'B004GLQTG8',
#  'B004H23JXW',
#  'B004MK9VLS',
#  'B004YBP8EY',
#  'B005B3OXWC',
#  'B006OU39QW',
#  'B006VH79R8',
#  'B00727AODC',
#  'B007LU0HU0',
#  'B007X6FFLS',
#  'B0081TDISI',
#  'B00836Y6B2',
#  'B008PAW5EQ',
#  'B0096DERAG',
#  'B0096QYH80',
#  'B009LRMQTG',
#  'B00A2V7BA4',
#  'B00A2V7ULY',
#  'B00A408AF8',
#  'B00A7F57EM',
#  'B00A7F5M9W',
#  'B00ACZ0DUA',
#  'B00B5081MI',
#  'B00BV1MVJ0',
#  'B00CEKXJ3Y',
#  'B00CEKXZA6',
#  'B00CGIULGC',
#  'B00CQAODG4',
#  'B00CS2ZWKQ',
#  'B00D35Z6OE',
#  'B00D99ZBR6',
#  'B00E45043A',
#  'B00E6FGSHY',
#  'B00E8TGT1S',
#  'B00EP2BN00',
#  'B00F1HVZ0Q',
#  'B00F2SKPIM',
#  'B00F3JPKCG',
#  'B00F9RRVUG',
#  'B00FTV382C',
#  'B00G9G0HTI',
# ...

# %%
total_df.isna().sum()
total_df.isnull().sum()
total_df.dropna
# Out:
# <bound method DataFrame.dropna of              asin               name  rating  verified
# 0      B0000SX2UC              Janet       3     False
# 1      B0000SX2UC         Luke Wyatt       1     False
# 2      B0000SX2UC             Brooke       5     False
# 3      B0000SX2UC      amy m. teague       3     False
# 4      B0000SX2UC      tristazbimmer       4     False
# ...           ...                ...     ...       ...
# 67981  B081H6STQQ              jande       5     False
# 67982  B081H6STQQ            2cool4u       5     False
# 67983  B081H6STQQ              simon       5     False
# 67984  B081TJFVCJ  Tobiasz Jedrysiak       5      True
# 67985  B0825BB7SG      Owen Gonzalez       5     False
#
# [67986 rows x 4 columns]>

# %%
total_df["rating"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        3
# 1        1
# 2        5
# 3        3
# 4        4
#         ..
# 67981    5
# 67982    5
# 67983    5
# 67984    5
# 67985    5
# Name: rating, Length: 67986, dtype: int64>

# %%
userInput = [
            {'asin':'B0000SX2UC', 'rating':5},
            {'asin':'B081H6STQQ', 'rating':3},
            {'asin':'B0000SX2UC', 'rating':2},
            {'asin':"B0029F2O3A", 'rating':5},
            
         ] 
inputMobile=pd.DataFrame(userInput)
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7fbc1ed8fcd0>>

# %%
total_df=total_df.drop("verified",axis=1)

# %%
userSubset = total_df[total_df['asin'].isin(inputMobile['asin'].tolist())]
userSubset.head()
# Out:
#          asin           name  rating
# 0  B0000SX2UC          Janet       3
# 1  B0000SX2UC     Luke Wyatt       1
# 2  B0000SX2UC         Brooke       5
# 3  B0000SX2UC  amy m. teague       3
# 4  B0000SX2UC  tristazbimmer       4

# %%
userSubset.shape
# Out:
# (102, 3)

# %%
userSubsetGroup = userSubset.groupby(['name'])
userSubsetGroup = sorted(userSubsetGroup,  key=lambda x: len(x[1]), reverse=True)
userSubsetGroup[0:3]
# Out:
# [('Amazon Customer',
#                asin             name  rating
#   9      B0000SX2UC  Amazon Customer       3
#   67941  B081H6STQQ  Amazon Customer       5
#   67946  B081H6STQQ  Amazon Customer       5
#   67951  B081H6STQQ  Amazon Customer       5),
#  ('2cool4u',
#                asin     name  rating
#   67982  B081H6STQQ  2cool4u       5),
#  ('A-la Dawn',
#             asin       name  rating
#   98  B0029F2O3A  A-la Dawn       5)]

# %%
pearsonCorrelationDict = {}

for name, group in userSubsetGroup:
    group = group.sort_values(by='asin')
    inputMobile = inputMobile.sort_values(by='asin')
    nRatings = len(group)
    temp_df = inputMobile[inputMobile['asin'].isin(group['asin'].tolist())]
    tempRatingList = temp_df['rating'].tolist()
    tempGroupList = group['rating'].tolist()
    Sxx = sum([i**2 for i in tempRatingList]) - pow(sum(tempRatingList),2)/float(nRatings)
    Syy = sum([i**2 for i in tempGroupList]) - pow(sum(tempGroupList),2)/float(nRatings)
    Sxy = sum( i*j for i, j in zip(tempRatingList, tempGroupList)) - sum(tempRatingList)*sum(tempGroupList)/float(nRatings)
    
    if Sxx != 0 and Syy != 0:
        pearsonCorrelationDict[name] = Sxy/sqrt(Sxx*Syy)
    else:
        pearsonCorrelationDict[name] = 0

# %%
pearsonCorrelationDict.items()
# Out:
# dict_items([('Amazon Customer', -0.8006407690254357), ('2cool4u', 0), ('A-la Dawn', 0), ('Aditya A.', 0), ('Alejandro Moreno', 0), ('Aucifer', 0), ('B. Hopper', 0), ('Bialynia', 0), ('Bob', 0), ('Bob H', 0), ('Brittler', 0), ('Brooke', 0), ('Ch', 0), ('Charles Cook', 0), ('CharlesG', 0), ('Chrissy Mendes', 0), ('Cindy Cowles', 0), ('Cspell', 0), ('D. Kashmiri', 0), ('Dale E. Owens III', 0), ('Dave D.', 0), ('Dean', 0), ('DebraJ', 0), ('Dilip', 0), ('Dr. Stuart Gitlow', 0), ('E. Stidd', 0), ('Eduardo T.', 0), ('Erik Lindstrom', 0), ('F1racer', 0), ('Gclancer', 0), ('Geraldo f.', 0), ('Guillermo M.', 0), ('Hector T.', 0), ('Honest Reviewer', 0), ('Itiswhatitis', 0), ('J. White', 0), ('JB', 0), ('Janet', 0), ('Jeff', 0), ('Jeremy Venturino', 0), ('Jerry Helsing', 0), ('Jixue Yang', 0), ('Jody', 0), ('John Doe', 0), ('Joseth garcia', 0), ('Kaity Lynn', 0), ('Karen S. Baird', 0), ('Kenneth Michael Mcneil', 0), ('Kyle Griswold', 0), ('Los Kositos', 0), ('Luke Wyatt', 0), ('M. Brennan', 0),
# ...

# %%
pearsonDF = pd.DataFrame.from_dict(pearsonCorrelationDict, orient='index')
pearsonDF.columns = ['similarityIndex']
pearsonDF['name'] = pearsonDF.index
pearsonDF.index = range(len(pearsonDF))
pearsonDF.head()
# Out:
#    similarityIndex              name
# 0        -0.800641   Amazon Customer
# 1         0.000000           2cool4u
# 2         0.000000         A-la Dawn
# 3         0.000000         Aditya A.
# 4         0.000000  Alejandro Moreno

# %%
topUsers=pearsonDF.sort_values(by='similarityIndex', ascending=False)[0:50]
topUsers.head()
# Out:
#     similarityIndex                name
# 49              0.0         Los Kositos
# 74              0.0  Susan J. Brillhart
# 72              0.0          SoundFreak
# 71              0.0                Sony
# 70              0.0        Somchay Thao

# %%
topUsersRating=topUsers.merge(total_df, left_on='name', right_on='name', how='inner')
topUsersRating.head()
# Out:
#    similarityIndex                name        asin  rating
# 0              0.0         Los Kositos  B07PHQ7FBP       5
# 1              0.0         Los Kositos  B081H6STQQ       5
# 2              0.0  Susan J. Brillhart  B0029F2O3A       5
# 3              0.0          SoundFreak  B07PHQ7FBP       1
# 4              0.0          SoundFreak  B081H6STQQ       1
